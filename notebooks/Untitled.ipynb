# %%
from chromadb.api import Client
from chromadb.config import Settings

client = Client(Settings(
    chroma_api_impl="rest",
    chroma_server_host="localhost",  # or public IP or container host
    chroma_server_http_port=8000
))

collection = client.get_or_create_collection("web_docs")
collection.add(
    documents=["example content here"],
    ids=["doc1"]
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:63, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      61 try:
#      62     # Equivalent to import onnxruntime
# ---> 63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
#
# File C:\ProgramData\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# ...
